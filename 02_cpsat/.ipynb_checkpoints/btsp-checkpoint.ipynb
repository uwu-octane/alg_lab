# %%
# Imports

# %%
# %load_ext autoreload
# %autoreload 2

# libraries
import networkx as nx
import random
import matplotlib
import matplotlib.pyplot as plt
import signal
import time

# our code
from _solver import squared_distance, BTSPSolverCP
import _solver_add_circuit as solver2

# %%
## Utils

# %%
def random_points(n, w=10_000, h=10_000):
    """
    Generate a list of n randomly placed points on the w x h grid.
    """
    return [(random.randint(0,w), random.randint(0,h)) for _ in range(n)]

def draw_btsp_edges(edges):
    """
    Draw the edges of a DBST. The bottleneck edge(s) automatically get highlighted.
    """
    points = set([e[0] for e in edges] + [e[1] for e in edges])
    draw_graph = nx.empty_graph()
    draw_graph.add_nodes_from(points)
    draw_graph.add_edges_from(edges)
    g_edges = draw_graph.edges()
    max_length = max((squared_distance(*e) for e in g_edges))
    color = [('red' if squared_distance(*e) == max_length else 'black') for e in g_edges]
    width = [(1.0 if squared_distance(*e) == max_length else 0.5) for e in g_edges]
    plt.clf()
    fig, ax = plt.gcf(), plt.gca()
    fig.set_size_inches(8,8)
    ax.set_aspect(1.0)  # 1:1 aspect ratio
    nx.draw_networkx(draw_graph, pos={p: p for p in points}, node_size=8,
                     with_labels=False, edgelist=g_edges, edge_color=color, width=width, ax=ax)
    plt.show()

# %%
#random.seed(1234567) # remove if you want random instances
solver = BTSPSolverCP(random_points(3))
draw_btsp_edges(solver.solve())

# %%
#random.seed(1234567) # remove if you want random instances
solver = BTSPSolverCP(random_points(5))
draw_btsp_edges(solver.solve())

# %%
random.seed(1234567) # remove if you want random instances
solver = BTSPSolverCP(random_points(10))
draw_btsp_edges(solver.solve())

# %%
## Benchmark

# %%
random.seed(1234567)  # remove if you want random instances
signal.signal(signal.SIGALRM, lambda signum,
                                    frame: print('\nYour time is over'))

signal.alarm(60)
start = time.time()

for i in range(3, 200):
    print(f'Points: {i}')
    BTSPSolverCP(random_points(i))
signal.alarm(0)
print(f'Time taken: {round(time.time() - start, 4)}')
# Out:
# Points: 3
# Points: 4
# Points: 5
# Points: 6
# Points: 7
# Points: 8
# Points: 9
# Points: 10
# Points: 11
# Points: 12
# Points: 13
# Points: 14
# Points: 15
# Points: 16
# Points: 17
# Points: 18
# Points: 19
# Points: 20
# Points: 21
# Points: 22
# Points: 23
# Points: 24
# Points: 25
# Points: 26
# Points: 27
# Points: 28
# Points: 29
# Points: 30
# Points: 31
# Points: 32
# Points: 33
# Points: 34
# Points: 35
# Points: 36
# Points: 37
# Points: 38
# Points: 39
# Points: 40
# Points: 41
# Points: 42
# Points: 43
# Points: 44
# Points: 45
# Points: 46
# Points: 47
# Points: 48
# Points: 49
# Points: 50
# Points: 51
# Points: 52
# Points: 53
# Points: 54
# Points: 55
# Points: 56
# Points: 57
# Points: 58
# Points: 59
# Points: 60
# Points: 61
# Points: 62
# Points: 63
# Points: 64
# Points: 65
# Points: 66
# Points: 67
# Points: 68
# Points: 69
# Points: 70
# Points: 71
# Points: 72
# Points: 73
# Points: 74
# Points: 75
# Points: 76
# Points: 77
# Points: 78
# Points: 79
# Points: 80
# Points: 81
# Points: 82
# Points: 83
# Points: 84
# Points: 85
# Points: 86
# Points: 87
# Points: 88
# Points: 89
# Points: 90
# Points: 91
# Points: 92
# Points: 93
# Points: 94
# Points: 95
# Points: 96
# Points: 97
# Points: 98
# Points: 99
# Points: 100
# Points: 101
# Points: 102
# Points: 103
# Points: 104
# Points: 105
# Points: 106
# Points: 107
# Points: 108
# Points: 109
# Points: 110
# Points: 111
# Points: 112
# Points: 113
# Points: 114
# Points: 115
# Points: 116
# Points: 117
# Points: 118
# Points: 119
# Points: 120
# Points: 121
# Points: 122
# Points: 123
# Points: 124
# Points: 125
# Points: 126
# Points: 127
# Points: 128
# Points: 129
# Points: 130
#
# Your time is over
# Points: 131
# Points: 132
# Points: 133
# Points: 134
# Points: 135
# Points: 136
# Points: 137
# Points: 138
# Points: 139
# Points: 140
# Points: 141
# Points: 142
# Points: 143
# Points: 144
# Points: 145
# Points: 146
# Points: 147
# Points: 148
# Points: 149
# Points: 150
# Points: 151
# Points: 152
# Points: 153
# Points: 154
# Points: 155
# Points: 156
# Points: 157
# Points: 158
# Points: 159
# Points: 160
# Points: 161
# Points: 162
# Points: 163
# Points: 164
# Points: 165
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 10
#       8 for i in range(3, 200):
#       9     print(f'Points: {i}')
# ---> 10     BTSPSolverCP(random_points(i))
#      11 signal.alarm(0)
#      12 print(f'Time taken: {round(time.time() - start, 4)}')
#
# File ~/alg-praktikum/algorithmik-praktikum-sose2023-gruppe-5/02_cpsat/_solver.py:95, in BTSPSolverCP.__init__(self, points)
#      93 self.__add_bottleneck_constraints()
#      94 self.__add_degree_constraints()
# ---> 95 self.__add_depth_constraints()
#
# File ~/alg-praktikum/algorithmik-praktikum-sose2023-gruppe-5/02_cpsat/_solver.py:80, in BTSPSolverCP.__add_depth_constraints(self)
#      78     continue
#      79 else:
# ---> 80     self.model.Add(self.depth_vars[w] == self.depth_vars[v] + 1).OnlyEnforceIf(x_vw)
#
# File ~/alg-praktikum/anaconda3/envs/alglab/lib/python3.10/site-packages/ortools/sat/python/cp_model.py:323, in LinearExpr.__add__(self, arg)
#     322 def __add__(self, arg):
# --> 323     if cmh.is_zero(arg):
#     324         return self
#     325     return _Sum(self, arg)
#
# File ~/alg-praktikum/anaconda3/envs/alglab/lib/python3.10/site-packages/ortools/sat/python/cp_model_helper.py:37, in is_zero(x)
#      35 def is_zero(x):
#      36     """Checks if the x is 0 or 0.0."""
# ---> 37     return (is_integral(x) and int(x) == 0) or (is_a_number(x) and
#      38                                                 float(x) == 0.0)
#
# File ~/alg-praktikum/anaconda3/envs/alglab/lib/python3.10/site-packages/ortools/sat/python/cp_model_helper.py:29, in is_a_number(x)
#      25     """Checks if x has either a number.Integral or a np.integer type."""
#      26     return isinstance(x, numbers.Integral) or isinstance(x, np.integer)
# ---> 29 def is_a_number(x):
#      30     """Checks if x has either a number.Number or a np.double type."""
#      31     return isinstance(x, numbers.Number) or isinstance(
#      32         x, np.double) or isinstance(x, np.integer)
#
# KeyboardInterrupt:

# %%
# Add Circuit

# %%
random.seed(1234567)  # remove if you want random instances
signal.signal(signal.SIGALRM, lambda signum,
                                    frame: print('\nYour time is over'))

signal.alarm(60)
start = time.time()
for i in range(3, 200):
    print(f'Points: {i}')
    solver2.BTSPSolverCP(random_points(i))
signal.alarm(0)
print(f'Time taken: {round(time.time() - start, 4)}')
