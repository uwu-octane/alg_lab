# %%
from typing import Set


from solver import BTSPSolverSAT
from util import random_points, draw_edges, export_instance, import_instance

# %%
# %load_ext autoreload
# %autoreload 2

# %%
points = import_instance("15.json")
solver = BTSPSolverSAT(points, 2)
edges, time_taken = solver.solve(0)
print("Time taken: " + str(time_taken))
draw_edges(edges)
# Out:
# New best bottleneck: 5406.7981282825795!
# The bottleneck 3712.45538693733 is infeasible!
# New best bottleneck: 3909.7826026519683!
# The bottleneck 3767.5440276126833 is infeasible!
# The bottleneck 3847.4679985673697 is infeasible!
# Time taken: 0.9905750340000026

# %%
for i in range(5,16):
    export_instance(str(i)+".json",random_points(i))

# %%
def benchmark(points):
    solver = BTSPSolverSAT(points, 2)
    with suppress_stdout():
        edges, time_taken = solver.solve(0)
    print("Method: Binary Search; Time taken: " + str(time_taken))
    
    with suppress_stdout():
        edges, time_taken = solver.solve(1)
    print("Method Linear Search Descending; Time taken: " + str(time_taken))
    
    with suppress_stdout():
        edges, time_taken = solver.solve(2)
    print("Method Linear Search Ascending; Time taken: " + str(time_taken))

# %%
benchmark(import_instance("15.json"))
# Out:
# New best bottleneck: 5406.7981282825795!
# The bottleneck 3712.45538693733 is infeasible!
# New best bottleneck: 3909.7826026519683!
# The bottleneck 3767.5440276126833 is infeasible!
# The bottleneck 3847.4679985673697 is infeasible!
# Method: Binary Search; Time taken: 1.0000136860000097
# The bottleneck 763.1749471779062 is infeasible!
# The bottleneck 1140.0535075162043 is infeasible!
# The bottleneck 1498.346421893148 created an unconnected graph!
# The bottleneck 1509.8244931116994 created an unconnected graph!
# The bottleneck 1593.2683389812275 created an unconnected graph!
# The bottleneck 1618.0092706780144 created an unconnected graph!
# The bottleneck 1652.2654145142662 created an unconnected graph!
# The bottleneck 1766.865020311399 created an unconnected graph!
# The bottleneck 1875.4692746083579 created an unconnected graph!
# The bottleneck 1880.6647760831806 created an unconnected graph!
# The bottleneck 1894.4656238633627 created an unconnected graph!
# The bottleneck 1959.1643626811917 created an unconnected graph!
# The bottleneck 2008.4765370797838 created an unconnected graph!
# The bottleneck 2180.0057339374134 created an unconnected graph!
# The bottleneck 2299.2564015350704 created an unconnected graph!
# The bottleneck 2619.55358792295 created an unconnected graph!
# The bottleneck 2643.5145166993125 created an unconnected graph!
# The bottleneck 2677.54850562973 created an unconnected graph!
# The bottleneck 2877.0001737921393 created an unconnected graph!
# The bottleneck 2899.5382390994605 created an unconnected graph!
# The bottleneck 2916.4370385797806 created an unconnected graph!
# The bottleneck 3054.7684036600876 created an unconnected graph!
# The bottleneck 3150.5791531082027 is infeasible!
# The bottleneck 3254.3916482193717 created an unconnected graph!
# The bottleneck 3304.629631290018 created an unconnected graph!
# The bottleneck 3328.593997471004 is infeasible!
# The bottleneck 3408.8056559446154 is infeasible!
# The bottleneck 3436.614904233525 is infeasible!
# The bottleneck 3461.555286283898 is infeasible!
# The bottleneck 3572.2017020319554 is infeasible!
# The bottleneck 3712.45538693733 is infeasible!
# The bottleneck 3763.7879855273463 is infeasible!
# The bottleneck 3767.5440276126833 is infeasible!
# The bottleneck 3847.4679985673697 is infeasible!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# Method Linear Search Descending; Time taken: 1.0250810780000421
# The bottleneck 763.1749471779062 is infeasible!
# The bottleneck 1140.0535075162043 is infeasible!
# The bottleneck 1498.346421893148 created an unconnected graph!
# The bottleneck 1509.8244931116994 created an unconnected graph!
# The bottleneck 1593.2683389812275 created an unconnected graph!
# The bottleneck 1618.0092706780144 created an unconnected graph!
# The bottleneck 1652.2654145142662 created an unconnected graph!
# The bottleneck 1766.865020311399 created an unconnected graph!
# The bottleneck 1875.4692746083579 created an unconnected graph!
# The bottleneck 1880.6647760831806 created an unconnected graph!
# The bottleneck 1894.4656238633627 created an unconnected graph!
# The bottleneck 1959.1643626811917 created an unconnected graph!
# The bottleneck 2008.4765370797838 created an unconnected graph!
# The bottleneck 2180.0057339374134 created an unconnected graph!
# The bottleneck 2299.2564015350704 created an unconnected graph!
# The bottleneck 2619.55358792295 created an unconnected graph!
# The bottleneck 2643.5145166993125 created an unconnected graph!
# The bottleneck 2677.54850562973 created an unconnected graph!
# The bottleneck 2877.0001737921393 created an unconnected graph!
# The bottleneck 2899.5382390994605 created an unconnected graph!
# The bottleneck 2916.4370385797806 created an unconnected graph!
# The bottleneck 3054.7684036600876 created an unconnected graph!
# The bottleneck 3150.5791531082027 is infeasible!
# The bottleneck 3254.3916482193717 created an unconnected graph!
# The bottleneck 3304.629631290018 created an unconnected graph!
# The bottleneck 3328.593997471004 is infeasible!
# The bottleneck 3408.8056559446154 is infeasible!
# The bottleneck 3436.614904233525 is infeasible!
# The bottleneck 3461.555286283898 is infeasible!
# The bottleneck 3572.2017020319554 is infeasible!
# The bottleneck 3712.45538693733 is infeasible!
# The bottleneck 3763.7879855273463 is infeasible!
# The bottleneck 3767.5440276126833 is infeasible!
# The bottleneck 3847.4679985673697 is infeasible!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# New best bottleneck: 3909.7826026519683!
# Method Linear Search Ascending; Time taken: 1.0266525360000287
