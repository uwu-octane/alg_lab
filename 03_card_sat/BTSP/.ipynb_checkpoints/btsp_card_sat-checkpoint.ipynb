# %%
from typing import Set


from solver import BTSPSolverSAT
from util import random_points, draw_edges

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
points = random_points(10)
solver = DBSTSolverSAT(points, 2)
edges = solver.solve()
draw_edges(edges)
# Out:
# New best bottleneck: 4041.5720951134845!
# The bottleneck 3333.5916066608997 is infeasible!
# New best bottleneck: 3729.0380797197554!
# The bottleneck 3493.1389895049983 is infeasible!
# The bottleneck 3544.661478900348 is infeasible!
# The bottleneck 3550.8839744491793 is infeasible!
# New best bottleneck: 3711.571230624572!
